# %%
# %%capture

# !pip install spacy
# !pip install corus
# !pip install num2words
# !pip install -q fasttext

# %%
# %%capture

import spacy
import pandas as pd
from corus import load_lenta2
from tqdm import tqdm
from numpy.linalg import norm
import numpy as np
from sklearn.base import BaseEstimator

from gensim.models.doc2vec import Doc2Vec, TaggedDocument

import re
import string
import nltk
from num2words import num2words
from scipy.spatial.distance import cosine
from sklearn.model_selection import GridSearchCV
import random

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
import time

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
import fasttext

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_res = pd.read_excel('/content/drive/MyDrive/vacancy_datasets/resume_train.xlsx')

# %%
res = pd.read_csv('/content/drive/MyDrive/vacancy_datasets/it_resume.csv')

# %%
job = pd.read_excel('/content/drive/MyDrive/vacancy_datasets/vacancies.xlsx')

# %%
job_train = pd.read_excel('/content/drive/MyDrive/vacancy_datasets/vacancy_train.xlsx')

# %% [markdown]
# #Подготовка тренировочных данных

# %% [markdown]
# Подготовим тренировочные данные по вакансиям на русском:

# %% [markdown]
# Объединим софт и хард скиллы в один столбец:

# %%
job_train['skills'] = ''

for row in range(len(job_train)):

  for i in range(0, len(job_train['hardSkills'][row].replace("[", "").replace("]", "").replace("{", "").replace("}", "").replace('"', "").split(',')), 3):
    job_train['skills'][row] = job_train['skills'][row] + ' ' + job_train['hardSkills'][row].replace("[", "").replace("]", "").replace("{", "").replace("}", "").replace('"', "").split(',')[i][job_train['hardSkills'][row].replace("[", "").replace("]", "").replace("{", "").replace("}", "").replace('"', "").split(',')[i].find('hard_skill_name') + 16:]

  for i in range(1, len(job_train['softSkills'][row].replace("[", "").replace("]", "").replace("{", "").replace("}", "").replace('"', "").split(',')), 3):
    job_train['skills'][row] = job_train['skills'][row] + ' ' + job_train['softSkills'][row].replace("[", "").replace("]", "").replace("{", "").replace("}", "").replace('"', "").split(',')[i][job_train['softSkills'][row].replace("[", "").replace("]", "").replace("{", "").replace("}", "").replace('"', "").split(',')[i].find('soft_skill_name') + 16:]

# %%
job_train[(job_train['hardSkills'] != '[]') & (job_train['softSkills'] != '[]')][['hardSkills', 'softSkills', 'skills']].iloc[0]
# Out:
# hardSkills    [{"hard_skill_name":"владение компьютером на у...
# softSkills    [{"owner_id":"2aee956e-562d-11ee-8e88-9586bb63...
# skills         владение компьютером на уровне уверенного пол...
# Name: 11, dtype: object

# %%
job_train_filter = job_train.drop(['hardSkills', 'softSkills', 'professionalSphereName', 'code_professional_sphere'], axis=1).fillna('')

# %%
job_train_filter
# Out:
#                                  additional_requirements  \
# 0
# 1
# 2
# 3       Официальное оформление, трудовой договор Режи...
# 4                                           0,25 ставки
# ...                                                  ...
# 68448
# 68449
# 68450     Условия:     работа на территории работодат...
# 68451
# 68452
#
#                                    position_requirements  \
# 0       1. Опыт работы в бюджетном учреждении (медици...
# 1                      Знание ПК, ворд, ехл, эл. почта.
# 2       знание 1С, налогового кодекса, владение прогр...
# 3       Высокий уровень владения и умения применять з...
# 4       Ответственность, коммуникабельность, умение р...
# ...                                                  ...
# 68448   Грузчик должен знать: правила погрузки и выгр...
# 68449   На должность механика по ремонту оборудования...
# 68450     Навыки чтения принципиальных схем и схем со...
# 68451   Среднее техническое образование, стаж работы ...
# 68452                        Опыт работы приветствуется
#
#                                position_responsibilities  \
# 0       1.Ведение бухгалтерского учета на участках ;У...
# 1       В бухгалтерскую фирму требуется Помощник бухг...
# 2                      Ведение бухгалтерской отчетности
# 3       Работа с системой "Клиент-Банк" (рублевые и в...
# 4       Сдача отчетности в архив, прием и отправка ко...
# ...                                                  ...
# 68448   Погрузка, выгрузка и внутрискладская перерабо...
# 68449   Знать устройство, технические характеристики ...
# 68450      Выполнение электромонтажных работ (вторичн...
# 68451   Выполнение работ по технической эксплуатации ...
# 68452                Продавца продовольственных товаров
#
#                                             vacancy_name  \
# 0                                              Бухгалтер
# 1                                              бухгалтер
# 2                                              Бухгалтер
# 3                                    Бухгалтер-экономист
# 4                                      Делопроизводитель
# ...                                                  ...
# 68448                                            Грузчик
# 68449                    механик по ремонту оборудования
# 68450                   Электромонтажник вторичных цепей
# 68451  Электромонтер стационарного радиооборудования ...
# 68452                 продавец продовольственных товаров
#
#                                             skills
# 0
# 1
# 2
# 3       бухгалтерский учет excel валютные операции
# 4
# ...                                            ...
# 68448
# 68449
# 68450
# 68451
# 68452
#
# [68453 rows x 5 columns]

# %%
# %%capture

job_train_filter['full_text'] = ''

columns = ['vacancy_name', 'additional_requirements', 'position_requirements', 'position_responsibilities', 'skills']

for i in tqdm(range(len(job_train_filter))):
    for col in columns:
        job_train_filter['full_text'][i] = job_train_filter['full_text'][i] + ' ' + str(job_train_filter[col][i])

# %% [markdown]
# Очистим данные:

# %%
nlp = spacy.load("en_core_web_sm")

# %%
job_train_filter['full_text'] = job_train_filter['full_text'].apply(lambda x: ' '.join(token.lemma_.lower() for token in nlp(x) if
        not token.is_punct # удаление пунктуации
        and not token.is_digit # удаление цифр
        and not token.like_num # удаление чисел, в том числе в виде текста
        and not token.is_space # удаление пробельных символов
    )
)

# %%
def tokenize(text):
	tokens = re.split(r'\W+', text)
	return tokens

stops = nltk.corpus.stopwords.words("russian")
bad_words = ['родился', 'родилась', 'январь', 'февраль', 'март', 'апрель', 'май', 'июнь', 'июль', 'август', 'сентябрь', 'октябрь', 'ноябрь', 'декабрь',
              'января', 'февраля', 'марта', 'апреля', 'мая', 'июня', 'июля', 'августа', 'сентября', 'октября', 'ноября', 'декабря']

wnl = WordNetLemmatizer()
def removeStopWords(text):
	text = [wnl.lemmatize(word) for word in text if (word not in stops) & (word not in bad_words)]
	return text

# %%
job_train_filter['full_text'] = job_train_filter['full_text'].apply(lambda x: tokenize(x))
job_train_filter['full_text'] = job_train_filter['full_text'].apply(lambda x: removeStopWords(x))
job_train_filter['join_full_text'] = job_train_filter['full_text'].apply(lambda x: ' '.join(x))

# %%
job_train_filter.to_csv('/content/job_train_filter.csv')

# %% [markdown]
# Подготовим тренировочные данные по резюме на русском:

# %%
train_res['full_text'] = train_res['Resume_text'].apply(lambda x: ' '.join(token.lemma_.lower() for token in nlp(x) if
        not token.is_punct # удаление пунктуации
        and not token.is_digit # удаление цифр
        and not token.like_num # удаление чисел, в том числе в виде текста
        and not token.is_space # удаление пробельных символов
    )
)

# %%
train_res['full_text'] = train_res['full_text'].apply(lambda x: tokenize(x))
train_res['full_text'] = train_res['full_text'].apply(lambda x: removeStopWords(x))
train_res['join_full_text'] = train_res['full_text'].apply(lambda x: ' '.join(x))

# %%
train_res['join_full_text'] = train_res['full_text'].apply(lambda x: ''.join(x))
job_train_filter['join_full_text'] = job_train_filter['full_text'].apply(lambda x: ''.join(x))

# %%
train_res.to_csv('/content/train_res.csv')

# %% [markdown]
# Соединим данные для обучения

# %%
# job_train_filter = pd.read_csv('/content/job_train_filter.csv')

# %%
# train_res = pd.read_csv('/content/train_res.csv')

# %%
train_res
# Out:
#      Unnamed: 0                                        Resume_text  \
# 0             0   DESIGNER Summary Designer with more than 15 y...
# 1             1   DESIGNER Summary Established well-rounded Des...
# 2             2   DESIGNER Summary To get a strong foothold on ...
# 3             3   DESIGNER / TECHNICAL DESIGNER Summary Creativ...
# 4             4   MULTIMEDIA DESIGNER AND GRAPHIC DESIGNER Port...
# ..          ...                                                ...
# 567         567   PHYSICAL THERAPIST TECHNICIAN Education Glenc...
# 568         568   ADMINISTRATIVE ASSISTANT Professional Summary...
# 569         569   CONCRETE LABORER/FINISHER/OPERATOR Profession...
# 570         570   HYDROBLASTING TECHNICIAN 1 Career Objective A...
# 571         571   UTILITY ENGINEER Profile Detail oriented and ...
#
#                                              full_text  \
# 0    ['designer', 'summary', 'designer', 'year', 'p...
# 1    ['designer', 'summary', 'establish', 'well', '...
# 2    ['designer', 'summary', 'get', 'strong', 'foot...
# 3    ['designer', 'technical', 'designer', 'summary...
# 4    ['multimedia', 'designer', 'graphic', 'designe...
# ..                                                 ...
# 567  ['physical', 'therapist', 'technician', 'educa...
# 568  ['administrative', 'assistant', 'professional'...
# 569  ['concrete', 'laborer', 'finisher', 'operator'...
# 570  ['hydroblasting', 'technician', 'career', 'obj...
# 571  ['utility', 'engineer', 'profile', 'detail', '...
#
#                                         join_full_text
# 0    ['designer', 'summary', 'designer', 'year', 'p...
# 1    ['designer', 'summary', 'establish', 'well', '...
# 2    ['designer', 'summary', 'get', 'strong', 'foot...
# 3    ['designer', 'technical', 'designer', 'summary...
# 4    ['multimedia', 'designer', 'graphic', 'designe...
# ..                                                 ...
# 567  ['physical', 'therapist', 'technician', 'educa...
# 568  ['administrative', 'assistant', 'professional'...
# 569  ['concrete', 'laborer', 'finisher', 'operator'...
# 570  ['hydroblasting', 'technician', 'career', 'obj...
# 571  ['utility', 'engineer', 'profile', 'detail', '...
#
# [572 rows x 4 columns]

# %%
all_data_train = pd.concat([train_res['join_full_text'], job_train_filter['join_full_text']], axis=0, ignore_index=True)

# %%
tagged_data = [TaggedDocument(words=text.lower().split(), tags=[f"doc_{idx}"]) for idx, text in enumerate(all_data_train)]

# %%
all_data_train
# Out:
# 0        ['designer', 'summary', 'designer', 'year', 'p...
# 1        ['designer', 'summary', 'establish', 'well', '...
# 2        ['designer', 'summary', 'get', 'strong', 'foot...
# 3        ['designer', 'technical', 'designer', 'summary...
# 4        ['multimedia', 'designer', 'graphic', 'designe...
#                                ...
# 69020    ['грузчик', 'грузчик', 'должен', 'знать', 'пра...
# 69021    ['механик', 'ремонту', 'оборудования', 'должно...
# 69022    ['электромонтажник', 'вторичных', 'цепей', 'ус...
# 69023    ['электромонтер', 'стационарного', 'радиообору...
# 69024    ['продавец', 'продовольственных', 'товаров', '...
# Name: join_full_text, Length: 69025, dtype: object

# %% [markdown]
# # Подготовка датасета с резюме

# %%
res.drop(['Unnamed: 0', 'Обновление резюме', 'Авто', 'index_prog'], axis=1, inplace=True)

# %% [markdown]
# Сделаем некоторую предобработку: выделим из столбцов признаки, поменяет ЗП в валюте в рубли, полный адрес заменим на город

# %%
# %%capture

res['move'] = 0

for row in range(res.shape[0]):
  if ('не готова к переезду' in res['Город, переезд, командировки'][row]) | ('не готов к переезду' in res['Город, переезд, командировки'][row]):
    res['move'].loc[row] = 0
  else:
    res['move'].loc[row] = 1

res['currency'] = res['ЗП'].apply(lambda x: x[x.find(' ') + 1:])
res['ЗП'] = res['ЗП'].apply(lambda x: x[:x.find(' ')])

if res['currency'][row] == 'USD':
    res['ЗП'][row] = int(res['ЗП'][row]) * 88

if res['currency'][row] == 'KZT':
    res['ЗП'][row] = int(res['ЗП'][row]) * 0.2

if res['currency'][row] == 'бел.руб.':
    res['ЗП'][row] = int(res['ЗП'][row]) * 28

res = res[(res['currency'] == 'руб.') | (res['currency'] == 'USD') | (res['currency'] == 'KZT') | (res['currency'] == 'бел.руб.')]
res.drop('currency', axis = 1, inplace=True)

# %%
res.reset_index(inplace=True, drop=True)

# %%
for row in range(res.shape[0]):
  res['ЗП'][row] = int(res['ЗП'][row])

# %%
# %%capture

res['Город, переезд, командировки'] = res['Город, переезд, командировки'].apply(lambda x: x[:x.find(' ')])
res['Образование и ВУЗ'] = res['Образование и ВУЗ'].apply(lambda x: x[:x.find('образование') + 11])

# %% [markdown]
# Разделим резюме по категориям, в зависимости от ожидаемой ЗП:

# %%
res['category'] = 0

res.loc[res['ЗП'] < 40000, 'category'] = 1
res.loc[(res['ЗП'] >= 40000) & (res['ЗП'] < 60000), 'category'] = 2
res.loc[(res['ЗП'] >= 60000) & (res['ЗП'] < 100000), 'category'] = 3
res.loc[(res['ЗП'] >= 100000) & (res['ЗП'] < 150000), 'category'] = 4
res.loc[(res['ЗП'] >= 150000) & (res['ЗП'] < 200000), 'category'] = 5
res.loc[(res['ЗП'] >= 200000) & (res['ЗП'] < 300000), 'category'] = 6
res.loc[res['ЗП'] >= 300000, 'category'] = 7

# %%
res['category'].value_counts()
# Out:
# 3    2358
# 1    1939
# 2    1805
# 4    1783
# 5    1076
# 6     748
# 7     215
# Name: category, dtype: int64

# %% [markdown]
# Создадим столбец для хранения текстовой информации и последующей предобработки:

# %%
# %%capture

res['full_text'] = ''

columns = ['Ищет работу на должность:', 'Занятость', 'График', 'Опыт работы', 'Последняя/нынешняя должность',
       'Образование и ВУЗ']

for i in tqdm(range(len(res))):
    for col in columns:
        res['full_text'][i] = res['full_text'][i] + ' ' + str(res[col][i])

# %%
res['full_text'][0]
# Out:
# ' веб разработчик html css js php базы данных фреймворки дизайн интерфейсы cms частичная занятость, проектная работа, полная занятость гибкий график, удаленная работа Опыт работы 18 лет 9 месяцев  Август 2017 — Апрель  2019 1 год 9 месяцев OpenSoft Саратов , www.opensoftdev.ru Информационные технологии, системная интеграция, интернет ... Системная интеграция, автоматизации технологических и бизнес-процессов предприятия, ИТ-консалтинг Инженер-программист Разработка и поддержка сайтов на корпоративной CMS и на WordPress; разработка корпоративной CMS; дизайн, вёрстка, улучшение интерфейсов существующих сайтов, основанных на разных фреймворках и CMS; консультации и техническая поддержка.  Октябрь 2006 — Июнь  2018 11 лет 9 месяцев СГУ им. Н.Г. Чернышевского Саратовская область , www.sgu.ru/ Преподаватель, научный руководитель Преподаватель (растровая компьютерная графика, разработка интерфейсов, PHP, JavaScript, фотография и др. дисциплины)  Июнь 2013 — Сентябрь  2017 4 года 4 месяца MIF Technology miftechnology.com/ Информационные технологии, системная интеграция, интернет ... Разработка программного обеспечения Системная интеграция, автоматизации технологических и бизнес-процессов предприятия, ИТ-консалтинг Веб-разработчик Веб-разработка широкого профиля: проектирование, дизайн, вёрстка, многоязычные системы, базы данных, программирование, тестирование, консультации, техническая поддержка.  Апрель 2012 — Август  2012 5 месяцев Веб-Синергия Саратов Информационные технологии, системная интеграция, интернет ... Разработка программного обеспечения Веб-разработчик Полноценная разработка веб-приложения, посвящённого поиску и заказу книг в различных электронных библиотеках.  Сентябрь 2010 — Март  2012 1 год 7 месяцев IRESSOURCES Франция , iressources.com Веб-разработчик, верстальщик Вёрстка веб-страниц (кроссбраузерная, адаптивная, кроссплатформенная) для сложных макетов, дизайн, разработка социальных сетей и фрагментов сайтов (мультиязычных и на французском / английском языках).  Апрель 2008 — Август  2010 2 года 5 месяцев ЛАР, ООО Россия , www.lar.ru Верстальщик Вёрстка веб-страниц (кроссбраузерная, кроссскринная, кроссплатформенная) для сложных макетов, дизайн, разработка веб-приложений на PHP / MySQL.  Август 2005 — Март  2008 2 года 8 месяцев ГУ РОПЕ «Неделя области» Саратов , www.nedelia.ru Верстальщик, веб-дизайнер, выпускающий редактор Полиграфическая вёрстка, создание и поддержка сайта газеты  Сентябрь 2002 — Июль  2005 2 года 11 месяцев ООО «Медиа-Саратов» Саратов , www.bogatej.ru/ Верстальщик, веб-дизайнер, корректор Полиграфическая вёрстка, создание и поддержка сайта газеты  Январь 2002 — Май  2004 2 года 5 месяцев Школа №105 Саратов Образовательные учреждения ... Школа, детский сад Учитель информатики Собственный курс, включающий основы веб-разработки. Инженер-программист Высшее образование'

# %% [markdown]
# Очистим данные:

# %%
nlp = spacy.load("en_core_web_sm")

# %%
res['full_text'] = res['full_text'].apply(lambda x: ' '.join(token.lemma_.lower() for token in nlp(x) if
        not token.is_punct # удаление пунктуации
        and not token.is_digit # удаление цифр
        and not token.like_num # удаление чисел, в том числе в виде текста
        and not token.is_space # удаление пробельных символов
        and not token.like_url
    )
)

# %%
res['full_text'] = res['full_text'].apply(lambda x: tokenize(x))
res['full_text'] = res['full_text'].apply(lambda x: removeStopWords(x))
res['full_text'] = res['full_text'].apply(lambda x: ' '.join(x))

# %%
res['full_text'][2257]
# Out:
# 'php разработчик javascript разработчик частичная занятость проектная работа полная занятость гибкий график полный день удаленная работа опыт работы года месяцев php разработчик javascript разработчик руб информационные технологии интернет телеком программирование разработка занятость частичная занятость проектная работа полная занятость график работы гибкий график полный день удаленная работа опыт работы года месяцев месяца the big d уфа backend разработчик удаленно backend месяцев the big d уфа backend разработчик backend месяца webhand москва информационные технологии системная интеграция интернет интернет компания поисковики платежные системы информационно познавательные развлекательные ресурсы продвижение сайтов прочее разработка программного обеспечения backend разработчик удаленно доработка поддерживаемых проектов месяцев startkomp уфа full stack разработчик разработка узкопрофильных веб приложений поддержка существующих проектов месяцев веб студия smarty дюртюли информационные технологии системная интеграция интернет интернет провайдер электроника приборостроение бытовая техника компьютеры оргтехника электронно вычислительная оптическая контрольно измерительная техника радиоэлектроника автоматика монтаж сервис ремонт телекоммуникации связь мобильная связь оптоволоконная связь спутниковая связь full stack разработчик разработка расширений модулей сайтов обслуживании месяцев фриланс веб дизайнер верстальщик занимался типичными лэндингами месяца ип ишмурзин р стерлитамак информационные технологии системная интеграция интернет интернет компания поисковики платежные системы информационно познавательные развлекательные ресурсы продвижение сайтов прочее разработка программного обеспечения веб дизайнер разработка дизайна сайта основной упор ux создание различной графики верстка ключевые навыки резюме открыто всему интернету изменить настройках видимости php javascript mysql верстка junior базы данных redis java возникли неполадки попробуйте обо быстро обучаюсь проект интересный работаю раза быстрее хочется опыта высоконагруженном проекте имею свои собственные проекты полноценные разработки интересовала именно веб разработка любимый язык php также разрабатывал nodejs однако востребованности начал терять навык втором разрабатывал приложения android хобби планах попробовать io высшее образование угктид информационные технологии автоматизированные системы управления знание языков русский родной английский b2 средне продвинутый татарский b1 средний гражданство время пути работы гражданство россия разрешение работу россия желательное время пути работы имеет значения опыт работы года месяцев месяца the big d уфа backend разработчик удаленно backend месяцев the big d уфа backend разработчик backend месяца webhand москва информационные технологии системная интеграция интернет интернет компания поисковики платежные системы информационно познавательные развлекательные ресурсы продвижение сайтов прочее разработка программного обеспечения backend разработчик удаленно доработка поддерживаемых проектов месяцев startkomp уфа full stack разработчик разработка узкопрофильных веб приложений поддержка существующих проектов месяцев веб студия smarty дюртюли информационные технологии системная интеграция интернет интернет провайдер электроника приборостроение бытовая техника компьютеры оргтехника электронно вычислительная оптическая контрольно измерительная техника радиоэлектроника автоматика монтаж сервис ремонт телекоммуникации связь мобильная связь оптоволоконная связь спутниковая связь full stack разработчик разработка расширений модулей сайтов обслуживании месяцев фриланс веб дизайнер верстальщик занимался типичными лэндингами месяца ип ишмурзин р стерлитамак информационные технологии системная интеграция интернет интернет компания поисковики платежные системы информационно познавательные развлекательные ресурсы продвижение сайтов прочее разработка программного обеспечения веб дизайнер разработка дизайна сайта основной упор ux создание различн ...

# %%
res.to_csv('/content/res.csv')

# %% [markdown]
# # Подготовка датасета с вакансиями

# %%
job.drop(['vac_title_tag', 'link'], axis=1, inplace=True)

# %%
job.fillna('', inplace=True)

# %%
job['salary'] = np.random.randint(30000, 350000, job.shape[0])

# %%
job['category'] = 0

job.loc[job['salary'] < 40000, 'category'] = 1
job.loc[(job['salary'] >= 40000) & (job['salary'] < 60000), 'category'] = 2
job.loc[(job['salary'] >= 60000) & (job['salary'] < 100000), 'category'] = 3
job.loc[(job['salary'] >= 100000) & (job['salary'] < 150000), 'category'] = 4
job.loc[(job['salary'] >= 150000) & (job['salary'] < 200000), 'category'] = 5
job.loc[(job['salary'] >= 200000) & (job['salary'] < 300000), 'category'] = 6
job.loc[job['salary'] >= 300000, 'category'] = 7

# %%
job['category'].value_counts()
# Out:
# 6    1709
# 5     834
# 4     808
# 7     749
# 3     612
# 2     357
# 1     166
# Name: category, dtype: int64

# %%
job['address'] = job['address'].apply(lambda x: x[:x.find(',')] if(x.find(',') != -1) else x)

# %%
job.head(10)
# Out:
#                        vacancy_title required_experience  \
# 0   .Net back-end developer (remote)             3–6 лет
# 1   .Net back-end developer (remote)             3–6 лет
# 2   .Net back-end developer (remote)             3–6 лет
# 3                   .NET разработчик            1–3 года
# 4                   .NET разработчик            1–3 года
# 5  .NET Разработчик (Web, .Net Core)            1–3 года
# 6        .NET разработчик (удалёнка)             3–6 лет
# 7               1C Developer Trainee        не требуется
# 8                          2D Artist            1–3 года
# 9                        2d Художник             3–6 лет
#
#                                          description  \
# 0  Velvetech is an American global software devel...
# 1  Velvetech is an American global software devel...
# 2  Velvetech is an American global software devel...
# 3  Привет! На связи deeplay — продуктовая IT-комп...
# 4  Привет! На связи deeplay — продуктовая IT-комп...
# 5  IT-Aces - Аккредитованная IT Компания, все льг...
# 6  NEXTEPIC - Объединяем профессионалов. Помогаем...
# 7   Покоряйте вершины с Aston! IT-компания ASTON ...
# 8  Чем предстоит заниматься: Отрисовка иконок, пр...
# 9  Октавиан Гейм Арт — это российская компания, с...
#
#                                               skills          address  \
# 0                         ASP.NET, MS SQL Server, C#           Алматы
# 1                         ASP.NET, MS SQL Server, C#             Баку
# 2                         ASP.NET, MS SQL Server, C#          Тбилиси
# 3            .NET Framework, C#, .NET Core, Git, ООП           Москва
# 4            .NET Framework, C#, .NET Core, Git, ООП      Новосибирск
# 5                                                           Ярославль
# 6  .NET Core, С#, SQL, Git, реляционные CУБД, инт...  Санкт-Петербург
# 7  1С: Предприятие 8, ERP-системы на базе 1С, сам...  Санкт-Петербург
# 8  Adobe Photoshop, Figma, Stable Diffusion, Arti...  Санкт-Петербург
# 9              Adobe Photoshop, Креативность, Дизайн  Санкт-Петербург
#
#                                  mode  salary  category
# 0  Полная занятость, удаленная работа   32386         1
# 1  Полная занятость, удаленная работа  217749         6
# 2  Полная занятость, удаленная работа  221834         6
# 3  Полная занятость, удаленная работа  131283         4
# 4  Полная занятость, удаленная работа   72907         3
# 5  Полная занятость, удаленная работа  184362         5
# 6  Полная занятость, удаленная работа   77103         3
# 7             Стажировка, полный день   84142         3
# 8       Полная занятость, полный день   41240         2
# 9       Полная занятость, полный день   80241         3

# %% [markdown]
# Сделаем колонку, где текстом будут записаны все данные

# %%
job['full_text'] = ''

# %%
job.columns
# Out:
# Index(['vacancy_title', 'required_experience', 'description', 'skills',
#        'address', 'mode', 'salary', 'category', 'full_text'],
#       dtype='object')

# %%
columns = ['vacancy_title', 'description', 'skills', 'mode']

# %%
for i in tqdm(range(len(job))):
    for col in columns:
        job['full_text'][i] = job['full_text'][i] + ' ' + str(job[col][i])
# Out:
#   0%|          | 0/5235 [00:00<?, ?it/s]<ipython-input-82-467c138444d3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   job['full_text'][i] = job['full_text'][i] + ' ' + str(job[col][i])
# 100%|██████████| 5235/5235 [00:07<00:00, 709.61it/s]

# %% [markdown]
# Очистка:

# %%
job['full_text'] = job['full_text'].apply(lambda x: ' '.join(token.lemma_.lower() for token in nlp(x) if
        not token.is_punct # удаление пунктуации
        and not token.is_digit # удаление цифр
        and not token.like_num # удаление чисел, в том числе в виде текста
        and not token.is_space # удаление пробельных символов
        and not token.like_url
    )
)

# %%
job['full_text'] = job['full_text'].apply(lambda x: tokenize(x))
job['full_text'] = job['full_text'].apply(lambda x: removeStopWords(x))
job['full_text'] = job['full_text'].apply(lambda x: ' '.join(x))

# %%
job['full_text'][0]
# Out:
# ' net back end developer remote velvetech be an american global software development company headquarter in chicago il velvetech have it developer strategically distribute in global technical job market to deliver the good in class software engineering and exceptional client service we have year of experience in software and hardware development for client all around the world especially for u client a an official microsoft gold partner our company be list in the top software development company in illinois usa usclient be lead trading and financial organization insurance company large healthcare association pharmaceutical and energy company equipment manufacturer hi tech startup etc area of expertise be consult development implementation and support of software solution we implement modern backend solution that support microservice architecture with the follow technology net core java sql server postgresql mongodb redis rabbitmq for the web ui front end development we opt for react or angular and for mobile development swift kotlin java most of the system be design for cloud infrastructure like aws azure gcp and heavily rely on docker kubernetes while modern ci cd be make use gitlab ci or teamcity in september velvetech llc receive the status of the official training provider of the international institute of business analysis this status give we the right to conduct regular quality training for business analyst and anyone perform ba activity regardless their job title principle be base on agile methodology scrum and kanban various project code in gitlab or github be build with multiple coordinate team collaborate via jira confluence m team and slack velvetech constantly follow the tech trend and actively cooperate with startup in such breakthrough area a machine learning the internet of thing blockchain fpga and ai responsibility a new team member will work fully remotely from the coziness of it home with many benefit and a competitive performance base salary with the ability to grow with we you will be build software use the language and technology of the net framework by work on our project you will be able to upgrade your skill in designing develop code customizing configuring testing and deploy in support of enterprise package solution develop and improve an application software and design technical architecture support by write technical and functional documentation implement software test and debug code while produce the design schema of a database support in make regular modification to exist software for error correction adaptation to new hardware and improve overall function and performance analyze customer need and keep up with change in technology requirement experience in the following technology net core sql database solid english level intermediate the following will be consider a an advantage experience with aws azure no sql database such a mongodb cassandra experience with docker kubernetes and linux terminal excellent troubleshooting and communication skill passion for technology and knowledge what we offer future project a highly loaded saas web base service for automate business process in the field of medicine insurance finance energy include module for process large datum array integration with external datum source mobile application and other benefit velvetech be in the top development company in the usa flexible work condition and a cooperative environment a competitive and performance base salary fair compensation and benefit many challenging and exciting project with new opportunity and learn growth opportunity skill and competency improvement and professional certification in company training english software devops project management design business our team we be a friendly team of professional where everyone be able to achieve high result and grow professionally not only due to their own knowledge and skill but also with the support of colleague value that we highly appreciate be high performanc ...

# %%
job.to_csv('/content/job.csv')

# %% [markdown]
# #Обучаем модель:

# %%
# %%time

model = Doc2Vec(vector_size=300, window=3, min_count=1, workers=4, epochs=20)
model.build_vocab(tagged_data)

for epoch in tqdm(range(model.epochs), desc="Training Doc2Vec"):
  model.train(tagged_data, total_examples=model.corpus_count, epochs=1)
# Out:
# Training Doc2Vec:   5%|▌         | 1/20 [00:23<07:33, 23.85s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  10%|█         | 2/20 [00:47<07:11, 23.97s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  15%|█▌        | 3/20 [01:12<06:48, 24.05s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  20%|██        | 4/20 [01:35<06:22, 23.88s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  25%|██▌       | 5/20 [01:59<05:59, 24.00s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  30%|███       | 6/20 [02:23<05:35, 23.97s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  35%|███▌      | 7/20 [02:46<05:04, 23.43s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  40%|████      | 8/20 [03:10<04:44, 23.68s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  45%|████▌     | 9/20 [03:34<04:21, 23.78s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  50%|█████     | 10/20 [03:56<03:53, 23.39s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  55%|█████▌    | 11/20 [04:21<03:32, 23.64s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  60%|██████    | 12/20 [04:45<03:10, 23.75s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  65%|██████▌   | 13/20 [05:07<02:43, 23.35s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  70%|███████   | 14/20 [05:31<02:21, 23.65s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  75%|███████▌  | 15/20 [05:55<01:58, 23.78s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  80%|████████  | 16/20 [06:18<01:33, 23.33s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  85%|████████▌ | 17/20 [06:42<01:10, 23.51s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  90%|█████████ | 18/20 [07:06<00:47, 23.67s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  95%|█████████▌| 19/20 [07:28<00:23, 23.22s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec: 100%|██████████| 20/20 [07:52<00:00, 23.60s/it]
# CPU times: user 10min 49s, sys: 22.4 s, total: 11min 11s
# Wall time: 7min 58s

# %% [markdown]
# Получим векторы для резюме:

# %%
res['vector'] = ''

for i in tqdm(range(len(res))):
  resume_vector = model.infer_vector(res['full_text'][i].split())
  res['vector'][i] = resume_vector
# Out:
# <ipython-input-130-55ba2e927ef2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res['vector'] = ''
#   0%|          | 0/9924 [00:00<?, ?it/s]<ipython-input-130-55ba2e927ef2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res['vector'][i] = resume_vector
# 100%|██████████| 9924/9924 [00:34<00:00, 287.86it/s]

# %% [markdown]
# А так же для вакансий:

# %%
job['vector'] = ''

for i in tqdm(range(len(job))):
  job_vector = model.infer_vector(job['full_text'][i].split())
  job['vector'][i] = job_vector
# Out:
#   0%|          | 0/5235 [00:00<?, ?it/s]<ipython-input-132-9e9a092863e1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   job['vector'][i] = job_vector
# 100%|██████████| 5235/5235 [00:11<00:00, 471.95it/s]

# %%
res.to_csv('/content/resume_vectors_final.csv')

# %%
job.to_csv('/content/job_vectors_final.csv')

# %% [markdown]
# # Ранжирование

# %% [markdown]
# Модель Doc2Vec: vector_size=300, window=3, min_count=1, workers=4, epochs=20

# %%
n = 6780

test_resume = res.iloc[n]['vector']
res.iloc[n]['Ищет работу на должность:']
# Out:
# 'инженер программист'

# %%
job['similarity_score'] = job['vector'].apply(lambda x: 1 - cosine(x, test_resume))

# %%
job.sort_values(['similarity_score'], ascending=False)[:3]['vacancy_title'].to_list()
# Out:
# ['Системный аналитик/исследователь',
#  'System Analyst Jun+/Middle',
#  'Разработчик (middle)']

# %% [markdown]
# Модель Doc2Vec: vector_size=500, window=5, min_count=3, workers=4, epochs=20

# %%
# %%time

model_1 = Doc2Vec(vector_size=500, window=5, min_count=3, workers=4, epochs=20)
model_1.build_vocab(tagged_data)

for epoch in tqdm(range(model_1.epochs), desc="Training Doc2Vec"):
  model_1.train(tagged_data, total_examples=model_1.corpus_count, epochs=1)
# Out:
# Training Doc2Vec:   5%|▌         | 1/20 [00:28<09:01, 28.50s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  10%|█         | 2/20 [00:56<08:26, 28.13s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  15%|█▌        | 3/20 [01:24<07:58, 28.14s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  20%|██        | 4/20 [01:52<07:26, 27.92s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  25%|██▌       | 5/20 [02:19<06:57, 27.85s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  30%|███       | 6/20 [02:49<06:36, 28.31s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  35%|███▌      | 7/20 [03:16<06:03, 27.97s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  40%|████      | 8/20 [03:43<05:33, 27.79s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  45%|████▌     | 9/20 [04:11<05:04, 27.68s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  50%|█████     | 10/20 [04:38<04:35, 27.52s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  55%|█████▌    | 11/20 [05:05<04:06, 27.43s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  60%|██████    | 12/20 [05:34<03:43, 27.95s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  65%|██████▌   | 13/20 [06:01<03:14, 27.73s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  70%|███████   | 14/20 [06:29<02:45, 27.57s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  75%|███████▌  | 15/20 [06:55<02:16, 27.23s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  80%|████████  | 16/20 [07:22<01:48, 27.19s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  85%|████████▌ | 17/20 [07:49<01:21, 27.08s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  90%|█████████ | 18/20 [08:16<00:54, 27.14s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  95%|█████████▌| 19/20 [08:45<00:27, 27.62s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec: 100%|██████████| 20/20 [09:12<00:00, 27.61s/it]
# CPU times: user 13min 22s, sys: 19.4 s, total: 13min 41s
# Wall time: 9min 15s

# %%
res['vector'] = ''

for i in tqdm(range(len(res))):
  resume_vector = model.infer_vector(res['full_text'][i].split())
  res['vector'][i] = resume_vector

job['vector'] = ''

for i in tqdm(range(len(job))):
  job_vector = model.infer_vector(job['full_text'][i].split())
  job['vector'][i] = job_vector
# Out:
# 100%|██████████| 9924/9924 [00:37<00:00, 264.95it/s]
# 100%|██████████| 5235/5235 [00:10<00:00, 516.94it/s]

# %%
n = 6780

test_resume = res.iloc[n]['vector']
res.iloc[n]['Ищет работу на должность:']
# Out:
# 'инженер программист'

# %%
job['similarity_score'] = job['vector'].apply(lambda x: 1 - cosine(x, test_resume))

# %%
job.sort_values(['similarity_score'], ascending=False)[:3]['vacancy_title'].to_list()
# Out:
# ['Системный аналитик/исследователь',
#  'System Analyst Jun+/Middle',
#  'Разработчик (middle)']

# %% [markdown]
# Модель Doc2Vec: vector_size=500, window=5, min_count=3, workers=4, epochs=20

# %%
# %%time

model_3 = Doc2Vec(vector_size=1000, window=5, min_count=3, workers=4, epochs=20)
model_3.build_vocab(tagged_data)

for epoch in tqdm(range(model_3.epochs), desc="Training Doc2Vec"):
  model_3.train(tagged_data, total_examples=model_3.corpus_count, epochs=1)
# Out:
# Training Doc2Vec:   5%|▌         | 1/20 [00:39<12:22, 39.05s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  10%|█         | 2/20 [01:16<11:31, 38.39s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  15%|█▌        | 3/20 [01:55<10:51, 38.30s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  20%|██        | 4/20 [02:32<10:07, 37.95s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  25%|██▌       | 5/20 [03:08<09:20, 37.34s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  30%|███       | 6/20 [03:46<08:43, 37.41s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  35%|███▌      | 7/20 [04:23<08:06, 37.45s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  40%|████      | 8/20 [05:00<07:27, 37.30s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  45%|████▌     | 9/20 [05:38<06:50, 37.31s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  50%|█████     | 10/20 [06:14<06:08, 36.87s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  55%|█████▌    | 11/20 [06:50<05:30, 36.69s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  60%|██████    | 12/20 [07:28<04:57, 37.22s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  65%|██████▌   | 13/20 [08:04<04:16, 36.62s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  70%|███████   | 14/20 [08:40<03:39, 36.59s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  75%|███████▌  | 15/20 [09:16<03:01, 36.25s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  80%|████████  | 16/20 [09:52<02:25, 36.41s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  85%|████████▌ | 17/20 [10:30<01:50, 36.81s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  90%|█████████ | 18/20 [11:06<01:12, 36.45s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec:  95%|█████████▌| 19/20 [11:42<00:36, 36.33s/it]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Training Doc2Vec: 100%|██████████| 20/20 [12:17<00:00, 36.86s/it]
# CPU times: user 18min 57s, sys: 19.3 s, total: 19min 16s
# Wall time: 12min 20s

# %%
res['vector'] = ''

for i in tqdm(range(len(res))):
  resume_vector = model.infer_vector(res['full_text'][i].split())
  res['vector'][i] = resume_vector

job['vector'] = ''

for i in tqdm(range(len(job))):
  job_vector = model.infer_vector(job['full_text'][i].split())
  job['vector'][i] = job_vector
# Out:
# 100%|██████████| 9924/9924 [00:34<00:00, 287.06it/s]
# 100%|██████████| 5235/5235 [00:10<00:00, 509.76it/s]

# %%
n = 999

test_resume = res.iloc[n]['vector']
res.iloc[n]['Ищет работу на должность:']
# Out:
# 'frontend разработчик'

# %%
job['similarity_score'] = job['vector'].apply(lambda x: cosine(x, test_resume))

# %%
job.sort_values(['similarity_score'], ascending=False)[:3]['vacancy_title'].to_list()
# Out:
# ['Middle frontend-разработчик (VUE)',
#  'Senior-frontend developer',
#  'Frontend-разработчик (React)']

# %% [markdown]
# Возьмем визуально лучшую модель и попробуем получить рекомендации для всех резюме:

# %% [markdown]
# Выдаем вакансиям id:

# %%
job['id'] = 0

for i in tqdm(range(len(job))):
  job['id'][i] = i
# Out:
# 100%|██████████| 5235/5235 [00:01<00:00, 2771.55it/s]

# %%
res['id'] = 0

for i in tqdm(range(len(res))):
  res['id'][i] = i
# Out:
# 100%|██████████| 9924/9924 [00:05<00:00, 1974.49it/s]

# %% [markdown]
# Найдем для каждого резюме три релевантные вакансии. Предварительно будем делать фильтрацию по зарплатной категории и городу.

# %%
res.reset_index(inplace=True, drop=True)
job.reset_index(inplace=True, drop=True)

# %%
res[['vac1', 'vac2', 'vac3']] = ''

for i in tqdm(range(len(res))):

  if res.iloc[i]['move'] == 0: # если переезд невозможен, смотрим только на вакансии в городе проживания
    data_for_match = job[(job['address'] == res.iloc[i]['Город, переезд, командировки']) & (job['category'] == res.iloc[i]['category'])] # также просматриваем вакансии только в подходящей зарплатной категории
    if len(data_for_match) < 3:
      data_for_match = job[(job['address'] == res.iloc[i]['Город, переезд, командировки'])] # если имеем меньше трех релевантных вакансий по данным фильтрам, ищем в той же локации, но с любой зарплатой
    if len(data_for_match) < 3:
      data_for_match = job
  else:
    data_for_match = job[(job['category'] == res.iloc[i]['category'])] # если переезд возможен, то не обращаем внимания на город
    if len(data_for_match) < 3:
      data_for_match = job # если имеем меньше трех релевантных вакансий по данным фильтрам, ищем с любой зарплатой

  resume_vec = res.iloc[i]['vector'] # получим вектор текущего резуме

  for j in range(len(data_for_match)):
    similarity_score = cosine(resume_vec, data_for_match.iloc[j]['vector']) # для каждой из отфильтрованных вакансий ищем косинусное сходство с текущим резюме
    data_for_match['similarity_score'][j] = similarity_score # записываем значение сходства для каждой вакансии

  data_for_match = data_for_match.sort_values(['similarity_score'], ascending=False)[:3] # сортируем по сходству и берем только 3 самых релевантных

  res['vac1'][i] = data_for_match.iloc[0]['id'] # в таблицу с резюме записываем id вакансий
  res['vac2'][i] = data_for_match.iloc[1]['id']
  res['vac3'][i] = data_for_match.iloc[2]['id']
# Out:
# 100%|██████████| 9924/9924 [1:41:43<00:00,  1.63it/s]

# %% [markdown]
# Обработка 9924 резюме заняла 1:41, в итоге на одно резюме ушло 0.61 сек

# %%
res[['id', 'vac1', 'vac2', 'vac3']]
# Out:
#         id  vac1  vac2  vac3
# 0        0   932  1467  1536
# 1        1  2398  2517  2493
# 2        2  1912  2195  2272
# 3        3  1634  1616  1626
# 4        4  2517  2493  1616
# ...    ...   ...   ...   ...
# 9919  9919  3725  1706  3719
# 9920  9920  4540   961  4136
# 9921  9921  3725  3231  3234
# 9922  9922  1912  1634   869
# 9923  9923  1683  1092  1100
#
# [9924 rows x 4 columns]

# %%
res[['id', 'vac1', 'vac2', 'vac3']].to_csv('/content/resume_matching_final.csv', index=False)

# %% [markdown]
# #Обучим модель fasttext:

# %%
with open('data_full.txt', 'w') as f:
  for i in range(3000):
    f.write(''.join(all_data_train.iloc[i]))
    f.write(' ')

# %%
# %%time

model_fasttext = fasttext.train_unsupervised('data_full_1.txt', model='skipgram', wordNgrams=3, dim=300, ws=3, minCount=1, epoch=20, thread=4, verbose=2)
# Out:
# CPU times: user 1h 40min 36s, sys: 18.9 s, total: 1h 40min 55s
# Wall time: 57min 6s

# %%
res['vector_fasttext'] = res['full_text'].apply(lambda x: model_fasttext.get_sentence_vector(x))
job['vector_fasttext'] = job['full_text'].apply(lambda x: model_fasttext.get_sentence_vector(x))

# %%
n = 3

test_resume = res.iloc[n]['vector_fasttext']
res.iloc[n]['Ищет работу на должность:']
# Out:
# 'ведущий программист 1c руководитель'

# %%
job['similarity_score_fasttext'] = job['vector_fasttext'].apply(lambda x: 1 - cosine(x, test_resume))

# %%
job.sort_values(['similarity_score_fasttext'], ascending=False)[:3]['vacancy_title'].to_list()
# Out:
# ['Разработчик 1С', 'Программист 1С', 'Ведущий программист 1С']

# %% [markdown]
# Посмотрим схожесть названий вакансий и резюме:

# %%
res['vector_title_fasttext'] = res['Ищет работу на должность:'].apply(lambda x: model_fasttext.get_sentence_vector(x))
job['vector_title_fasttext'] = job['vacancy_title'].apply(lambda x: model_fasttext.get_sentence_vector(x))

# %%
n = 3978

test_resume = res.iloc[n]['vector_title_fasttext']
res.iloc[n]['Ищет работу на должность:']
# Out:
# 'аналитик бизнес системный'

# %%
job['similarity_title_score_fasttext'] = job['vector_title_fasttext'].apply(lambda x: 1 - cosine(x, test_resume))

# %%
job.sort_values(['similarity_title_score_fasttext'], ascending=False)['vacancy_title'].unique()[:3]
# Out:
# array(['Бизнес / Системный аналитик', 'Системный/бизнес аналитик',
#        'Системный аналитик\\ Бизнес аналитик'], dtype=object)

# %% [markdown]
# Модель fasttext работает хорошо, даже лучше Doc2Vec

# %% [markdown]
# Попробуем смотреть топ-3 по сумме косинусной схожести между названиями и описаниями:

# %%
n = 3

test_resume = res.iloc[n]['vector_fasttext']
test_resume_title = res.iloc[n]['vector_title_fasttext']
res.iloc[n]['Ищет работу на должность:']
# Out:
# 'ведущий программист 1c руководитель'

# %%
job['similarity_score_fasttext'] = job['vector_fasttext'].apply(lambda x: 1 - cosine(x, test_resume))
job['similarity_title_score_fasttext'] = job['vector_title_fasttext'].apply(lambda x: 1 - cosine(x, test_resume_title))

# %%
job['sum_score'] = job['similarity_score_fasttext'] + job['similarity_title_score_fasttext']
job.sort_values(['sum_score'], ascending=False)[:3]['vacancy_title'].to_list()
# Out:
# ['Ведущий инженер-программист',
#  'Программист 1С/Ведущий специалист',
#  'Ведущий инженер-программист']

# %% [markdown]
# Сделаем визуализацию названий:

# %%
two_dimensional_array = np.array(job['vector_title_fasttext'].apply(pd.Series))

# %%
# Применение t-SNE для снижения размерности
tsne = TSNE(n_components=3, random_state=42)
X_tsne = tsne.fit_transform(np.array(two_dimensional_array))

# %%
plt.figure(figsize=(20, 10))
plt.xlim(-30, 10)
plt.ylim(-30, 5)
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], s=10)


for i, txt in enumerate(job['vacancy_title'][:100]):
    plt.annotate(txt, (X_tsne[i, 0], X_tsne[i, 1]), fontsize=8)

plt.title("Визуализация косинусного сходства названий вакансий при помощи FastText")
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1])

for i, txt in enumerate(res['Ищет работу на должность:'][:100]):
    plt.annotate(txt, (X_tsne[i, 0], X_tsne[i, 1]), fontsize=8)

plt.title("Визуализация косинусного сходства названий вакансий при помощи FastText")
plt.show()
